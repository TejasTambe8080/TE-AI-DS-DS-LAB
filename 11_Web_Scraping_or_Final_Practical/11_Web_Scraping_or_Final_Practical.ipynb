# %% [markdown]
# # Practical: Impala Database and Queries

# %%
# !pip install impyla
# Out:
# Collecting impyla
#   Downloading impyla-0.22.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: six in c:\users\dell\anaconda3\lib\site-packages (from impyla) (1.17.0)
# Collecting thrift==0.16.0 (from impyla)
#   Downloading thrift-0.16.0.tar.gz (59 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting thrift-sasl==0.4.3 (from impyla)
#   Downloading thrift_sasl-0.4.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting bitarray (from impyla)
#   Downloading bitarray-3.8.1-cp313-cp313-win_amd64.whl.metadata (35 kB)
# Collecting pure-sasl>=0.6.2 (from thrift-sasl==0.4.3->impyla)
#   Downloading pure-sasl-0.6.2.tar.gz (11 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Downloading impyla-0.22.0-py2.py3-none-any.whl (310 kB)
# Downloading thrift_sasl-0.4.3-py2.py3-none-any.whl (8.3 kB)
# Downloading bitarray-3.8.1-cp313-cp313-win_amd64.whl (150 kB)
# Building wheels for collected packages: thrift, pure-sasl
#   Building wheel for thrift (pyproject.toml): started
#   Building wheel for thrift (pyproject.toml): finished with status 'done'
#   Created wheel for thrift: filename=thrift-0.16.0-py3-none-any.whl size=196249 sha256=7be64570329b3151703b617acf7fa4ef2c8d8586cb529b73f61ec17aaf816f42
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\1d\c7\a6\20046e76dae40a1e88a82960183d8c9c21170ea80b2d0fb257
#   Building wheel for pure-sasl (pyproject.toml): started
#   Building wheel for pure-sasl (pyproject.toml): finished with status 'done'
#   Created wheel for pure-sasl: filename=pure_sasl-0.6.2-py3-none-any.whl size=11538 sha256=82b2821496ae06cfa35f20f9e8e9010939d5c1542f05f5ad8743fa404d3e6192
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\c0\73\e4\f14b024b2a94ee520b3b81ebd16f04a9baa06495b8d300ab77
# Successfully built thrift pure-sasl
# Installing collected packages: pure-sasl, bitarray, thrift, thrift-sasl, impyla
#
#    -------- ------------------------------- 1/5 [bitarray]
#    ---------------- ----------------------- 2/5 [thrift]
#    ---------------- ----------------------- 2/5 [thrift]
#    ---------------- ----------------------- 2/5 [thrift]
#    ---------------- ----------------------- 2/5 [thrift]
#    -------------------------------- ------- 4/5 [impyla]
#    -------------------------------- ------- 4/5 [impyla]
#    -------------------------------- ------- 4/5 [impyla]
#    -------------------------------- ------- 4/5 [impyla]
#    -------------------------------- ------- 4/5 [impyla]
#    -------------------------------- ------- 4/5 [impyla]
#    -------------------------------- ------- 4/5 [impyla]
#    -------------------------------- ------- 4/5 [impyla]
#    -------------------------------- ------- 4/5 [impyla]
#    -------------------------------- ------- 4/5 [impyla]
#    -------------------------------- ------- 4/5 [impyla]
#    -------------------------------- ------- 4/5 [impyla]
#    ---------------------------------------- 5/5 [impyla]
#
# Successfully installed bitarray-3.8.1 impyla-0.22.0 pure-sasl-0.6.2 thrift-0.16.0 thrift-sasl-0.4.3

# %%
import pandas as pd
import numpy as np

# %%
class ImpalaSimulator:
    def __init__(self):
        self.data = []
        self.current_db = None
        
    def execute(self, query):
        print(f"DEBUG: Executing Impala SQL -> {query}")
        if "INSERT INTO" in query:
            self.data = [ {'id': 1, 'name': 'John', 'age': 25},
                          {'id': 2, 'name': 'Jane', 'age': 30},
                          {'id': 3, 'name': 'Bob', 'age': 40}
                        ]
    def fetch_as_dataframe(self):
        return pd.DataFrame(self.data)

# %%
print("[TASK 1: DATABASE & TABLE CREATION]")

cursor = ImpalaSimulator()

cursor.execute("CREATE DATABASE my_database;")

cursor.execute("USE my_database;")

cursor.execute("CREATE TABLE my_table ( id INT, name STRING, age INT );")


print("\n[TASK 2: DATA INSERTION]")

cursor.execute(
    "INSERT INTO my_table VALUES "
    "(1, 'John', 25), "
    "(2, 'Jane', 30), "
    "(3, 'Bob', 40);"
)


print("\n[TASK 3: SIMPLE QUERY & DATA ANALYSIS]")

df = cursor.fetch_as_dataframe()

print("Original Data from Impala:")

print(df)


print("\n[TASK 4: DATA PREPROCESSING & NORMALIZATION]")


def normalize_age(column):

    return (column - column.min()) / (
        column.max() - column.min()
    )


df['age_normalized'] = normalize_age(df['age'])

print("Data after Normalization (Age scaled between 0 and 1):")

print(df)


print("\n[CONCLUSION]")

print("1. Successfully simulated Impala SQL commands (Create, Insert, Select).")

print("2. Loaded data into Python environment for analysis.")

print("3. Performed Data Preprocessing using Min-Max Normalization.")
# Out:
# [TASK 1: DATABASE & TABLE CREATION]
# DEBUG: Executing Impala SQL -> CREATE DATABASE my_database;
# DEBUG: Executing Impala SQL -> USE my_database;
# DEBUG: Executing Impala SQL -> CREATE TABLE my_table ( id INT, name STRING, age INT );
#
# [TASK 2: DATA INSERTION]
# DEBUG: Executing Impala SQL -> INSERT INTO my_table VALUES (1, 'John', 25), (2, 'Jane', 30), (3, 'Bob', 40);
#
# [TASK 3: SIMPLE QUERY & DATA ANALYSIS]
# Original Data from Impala:
#    id  name  age
# 0   1  John   25
# 1   2  Jane   30
# 2   3   Bob   40
#
# [TASK 4: DATA PREPROCESSING & NORMALIZATION]
# Data after Normalization (Age scaled between 0 and 1):
#    id  name  age  age_normalized
# 0   1  John   25        0.000000
# 1   2  Jane   30        0.333333
# 2   3   Bob   40        1.000000
#
# [CONCLUSION]
# 1. Successfully simulated Impala SQL commands (Create, Insert, Select).
# 2. Loaded data into Python environment for analysis.
# 3. Performed Data Preprocessing using Min-Max Normalization.
