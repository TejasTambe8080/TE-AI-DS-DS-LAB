# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Step 1: Load Academic Performance Dataset
#
# Dataset Name: StudentPerformanceFactors.csv

# %%
df = pd.read_csv('StudentPerformanceFactors.csv')
df.shape
# Out:
# (6607, 20)

# %% [markdown]
# # Display First Five Records

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %% [markdown]
# # Step 2: Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %% [markdown]
# # Step 3: Check Missing Values

# %%
print("Missing Values in Dataset:")

df.isnull().sum()
# Out:
# Missing Values in Dataset:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %% [markdown]
# # Handle Missing Values
#
# ## Technique Used
# - Numerical columns → Replace missing values using Mean
# - Categorical columns → Replace missing values using Mode

# %%
# Separate Numerical and Categorical Columns

numerical_cols = df.select_dtypes(include=np.number).columns

categorical_cols = df.select_dtypes(exclude=np.number).columns

# Fill Numerical Missing Values with Mean

for col in numerical_cols:
    df[col].fillna(df[col].mean(), inplace=True)

# Fill Categorical Missing Values with Mode

for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

print("Missing Values Handled Successfully")
# Out:
# Missing Values Handled Successfully
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4416\3203460826.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4416\3203460826.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %% [markdown]
# # Step 4: Check for Inconsistencies
#
# ## Inconsistencies Checked
# - Duplicate records
# - Invalid or repeated values

# %%
# Check Duplicate Records

print("Duplicate Records:", df.duplicated().sum())
# Out:
# Duplicate Records: 0

# %%
plt.figure(figsize=(17,5))
plt.subplot(1,2,1)
sns.distplot (df['Hours_Studied'])
plt.subplot(1,2,2)
sns.distplot(df['Attendance'])
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4416\1016007546.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot (df['Hours_Studied'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4416\1016007546.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Attendance'])

# %%
df['Hours_Studied']
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %% [markdown]
# # Step 5: Detect Outliers Using Boxplot

# %%
sns.boxplot(df['Hours_Studied'])
# Out:
# <Axes: ylabel='Hours_Studied'>

# %% [markdown]
# # Step 6: Detect Outliers Using IQR Method
#
# ## Formula
# - IQR = Q3 - Q1
# - Lower Limit = Q1 - 1.5 × IQR
# - Upper Limit = Q3 + 1.5 × IQR

# %%
percentile25 = df['Hours_Studied'].quantile(0.25)
percentile75 = df['Hours_Studied'].quantile(0.75)

IQR = percentile75 - percentile25

lower_limit = percentile25 - 1.5 * IQR
upper_limit = percentile75 + 1.5 * IQR



print("Lower Limit:", lower_limit)
print("Upper Limit:", upper_limit)
# Out:
# Lower Limit: 4.0
# Upper Limit: 36.0

# %%
df[(df['Hours_Studied'] < lower_limit)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 262               1          69                 High              Medium
# 1061              3          85                  Low                High
# 1101              3          62               Medium                 Low
# 1539              3          96                 High                High
# 1591              2          84                  Low                High
# 1971              2          96                  Low                High
# 2024              2          98                  Low                High
# 2947              2          67               Medium              Medium
# 3017              3          83                 High                 Low
# 3152              3          92                 High                 Low
# 3454              2          99               Medium                 Low
# 4033              3          79                  Low              Medium
# ...

# %%
df[(df['Hours_Studied'] > upper_limit)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 209              43          86                 High              Medium
# 478              38          86                  Low                High
# 1615             39          95               Medium                High
# 1957             39          97                 High                High
# 2035             37          94                 High              Medium
# 2305             39          92               Medium              Medium
# 2506             38          63               Medium                High
# 2521             38          86                 High              Medium
# 2895             44          68                 High                 Low
# 3241             37          96                 High              Medium
# 3716             39          90                 High                High
# 3982             39          75               Medium                High
# ...

# %%
new_df = df[(df['Hours_Studied'] >= lower_limit) & 
            (df['Hours_Studied'] <= upper_limit)]

new_df.shape
# Out:
# (6564, 20)

# %% [markdown]
# # Boxplot After Removing Outliers

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot (df['Hours_Studied'])
plt.subplot(2,2,2)
sns.boxplot(df['Hours_Studied'])
plt.subplot(2,2,3)
sns.distplot (new_df['Hours_Studied'])
plt.subplot(2,2,4)
sns.boxplot(new_df['Hours_Studied'])
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14232\352744737.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot (df['Hours_Studied'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14232\352744737.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# Apply Log Transformation

df['Log_Hours_Studied'] = np.log(df['Hours_Studied'])

df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions  ... Teacher_Quality School_Type  \
# ...

# %% [markdown]
# # Step 7: Apply Data Transformation
#
# ## Purpose of Transformation
# Log Transformation is applied to:
# - Reduce skewness
# - Improve data distribution
# - Convert non-normal distribution closer to normal distribution

# %%
plt.figure(figsize=(6,4))

sns.histplot(df['Hours_Studied'], kde=True)

plt.title("Before Transformation")

plt.show()

# %% [markdown]
# # Distribution After Log Transformation

# %%
plt.figure(figsize=(6,4))

sns.histplot(df['Log_Hours_Studied'], kde=True)

plt.title("After Log Transformation")

plt.show()

# %% [markdown]
# # Final Cleaned Dataset

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions  ... Teacher_Quality School_Type  \
# ...
