# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading the Titanic Dataset

# %%
df = pd.read_csv('Titanic-Dataset.csv')
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # Dataset Overview and Data Cleaning

# %%
df.info()
df.isnull().sum()
df.drop(['Cabin'],axis=1,inplace=True)
df["Age"].fillna(df["Age"].mean(),inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17688\130880767.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(),inplace=True)

# %% [markdown]
# #  Handling Missing Values in Embarked Column

# %%
df["Embarked"].value_counts()
df["Embarked"].fillna("s",inplace=True)
df.isnull().sum()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17688\2914398519.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Embarked"].fillna("s",inplace=True)
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # Statistical Summary of Dataset

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #  Survival Count Analysis

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Visualization of Survival Count

# %%
sns.countplot(x="Survived",data = df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# # Gender-wise Survival Analysis

# %%
sns.countplot(x="Sex",hue="Survived",data= df )
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# # Passenger Class vs Survival Analysis

# %%
sns.countplot(x="Pclass",hue="Survived",data= df )
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# # Embarked Port vs Survival Analysis

# %%
sns.countplot(x="Embarked",hue="Survived",data= df )
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# # Age vs Survival Analysis

# %%
sns.countplot(x="Age",hue="Survived",data= df )
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# # SibSp vs Survival Analysis

# %%
sns.countplot(x="SibSp",hue="Survived",data= df )
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %% [markdown]
# # Parch vs Survival Analysis

# %%
sns.countplot(x="Parch",hue="Survived",data= df )
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %% [markdown]
# # Parch vs Pclass Analysis

# %%
sns.countplot(x="Parch",hue="Pclass",data= df )
# Out:
# <Axes: xlabel='Parch', ylabel='count'>
